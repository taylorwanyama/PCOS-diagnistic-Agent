# %%
from IPython.display import Image, display
from ai_agent import app

# %%
img_bytes = app.get_graph().draw_mermaid_png()
with open("pcos_agent_graph.png", "wb") as f:
    f.write(img_bytes)

# Display in notebook
Image(filename="pcos_agent_graph.png")
